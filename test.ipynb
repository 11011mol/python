# %%
lang1 = ["C", "C++", "JAVA"]
lang2 = ["Python", "Go", "C#"]
lang1.extend(lang2)
print(lang1)

# %%
cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면", "소시지", "라면", "팥빙수", "김치전"]
print(len(cook))

# %%
nums = [1, 2, 3, 4, 5] 
print(sum(nums)/len(nums))

# %%
date = input("날짜(연/월/일)입력: ")
list1 = date.split("/")
print(list1)
print(f"입력한 날짜의 10년 후는 {int(list1[0])+10}년 {int(list1[1])}월 {list1[2]}일")
# Out:
# ['2023', '9', '15']
# 입력한 날짜의 10년 후는 2033년 9월 15일

# %%
nums = [1, 2, 3, 4, 5, 6, 7]
print("max:", max(nums))
print("max:", min(nums))

# %%
nums = [1, 2, 3, 4, 5, 6, 7]
print(sum(nums))

# %%
data = [2, 4, 3, 1, 5, 10, 9]
data.sort()
print(data)

# %%
a = int(input("첫 번째 정수를 입력하세요: "))
b = int(input("두 번째 정수를 입력하세요: "))
print(f"{a} + {b} = {a+b}")
print(f"{a} - {b} = {a-b}")
print(f"{a} * {b} = {a*b}")
print(f"{a} / {b} = {a/b}")

# %%
movie_rank = [ '닥터 스트레인지', '스플릿', '럭키']
movie_rank.append("배트맨")
movie_rank.insert(1,'슈퍼맨')
movie_rank.remove("럭키")
movie_rank.remove("스플릿")
movie_rank.remove("배트맨")
print(movie_rank)

# %%
grade = []
a = int(input("성적을 입력하세요: "))
grade.append(a)
b = int(input("성적을 입력하세요: "))
grade.append(b)
c = int(input("성적을 입력하세요: "))
grade.append(c)
d = int(input("성적을 입력하세요: "))
grade.append(d)
e = int(input("성적을 입력하세요: "))
grade.append(e)

print(f"성적 평균은 {sum(grade)/len(grade)}")

# %%
scores = [50, 60, 70, 80, 90]
scores.append(85)
print(max(scores))
print(min(scores))
scores.remove(min(scores))
scores.sort(reverse=True)
print(scores)

# %%
F = int(input("화씨온도: "))

C = (F -32)*5/9
print(f'섭씨온도:{C}')

# %%
def fahrenheit(F):
    C = (F -32)*5/9
    print(f'섭씨온도:{C}')
fahrenheit(5)
# Out:
# 섭씨온도:-15.0

# %%
rad = int(input("반지름을 입력하시오: "))
pi = 3.141592
print(f"원 둘레: {rad*2*pi}")
print(f"원 넓이: {rad**2*pi}")

# %%
def circle(rad):
    pi = 3.141592
    print(f"원 둘레: {rad*2*pi}")
    print(f"원 넓이: {rad**2*pi}")
circle(5.4)
# Out:
# 원 둘레: 33.929193600000005
# 원 넓이: 91.60882272000002

# %%
def change(mon, price):
    change = mon - price
    print(f"거스름돈: {change}")
    print(f"500원짜리: {change//500} 개")
    print(f"100원짜리: {change%500//100} 개")  
change(9000, 8000)
# Out:
# 거스름돈: 1000
# 500원짜리: 2 개
# 100원짜리: 0 개

# %%
mon = int(input("투입한 돈: "))
price = int(input("물건값: "))

change = mon - price
print(f"거스름돈: {change}")
print(f"500원짜리: {change//500} 개")
print(f"100원짜리: {change%500//100} 개")

# %%
def multiply(num1, num2):
    num3 = num1 * num2
    print(num3)
multiply(1, 2)
# Out:
# 2

# %%
def add(a, b):
    return a + b
res = add(1, 2)
print(res)
# Out:
# 3

# %%
def max_of_three(a, b, c):
    return max([a, b, c])
res = max_of_three(1, 2, 3)
print(res)
# Out:
# 3

# %%
def max_of_three(a, b, c):
    print(max([a, b, c]))
res = max_of_three(1, 2, 3)
print(res)
# Out:
# 3
# None

# %%
def addlist(list1, number1):
    list1.append(number1)
    return list1
res = addlist([1, 2, 3], 4)
print(res)
# Out:
# [1, 2, 3, 4]

# %%
def average(numbers):
    average = sum(numbers) / len(numbers)
    return average

list1 = [1, 2, 3, 4, 5]
res = average(list1)

print(res)
# Out:
# 3.0
