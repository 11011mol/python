# %%
a = 10       # 변수는 주소에 붙이는 "이름" 이자 데이터를 담는 공간
print(id(a)) # 주소(address)
# Out:
# 4356139896

# %%
# C 언어
# int a = 10 

# Python --> Dynamic Typing
a = 10

# %%
# 가능
a = 10

a1 = 11

a_1 = 12

# 불가능
'''
1a = 10
def = 10
'''

# %%
# type

a = 1
print(type(a))

b = 1.5
print(type(b))

c = "hello"
print(type(c))

d = 'python'
print(type(d))

e = "hello 'python'"
print(e)

f = 'hello "python"'
print(f)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# hello 'python'
# hello "python"
